# %%
import pandas as pd 
import numpy as np 
import warnings 
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("train.csv")
store = pd.read_csv("store.csv")

# %%
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
train.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %% [markdown]
# # fill the null values

# %%
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace=True)
store['CompetitionOpenSinceMonth'].fillna(0 , inplace=True)
store['CompetitionOpenSinceYear'].fillna(0 , inplace=True)
store['Promo2SinceWeek'].fillna(0 , inplace=True)
store['Promo2SinceYear'].fillna(0 , inplace=True)
store['PromoInterval'].fillna("None" , inplace=True)

# %%
# merge the file 
df = pd.merge(train, store, on='Store', how='left')

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
df.shape
# Out:
# (1017209, 18)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# lets clean the date
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by='Date')

# %%
# remove close store
df = df[df['Open'] == 1]

# %%
df.shape
# Out:
# (844392, 18)

# %%
# : Focus on ONE Store

df_store = df[df['Store'] == 1]

# %%
df_store = df_store[['Date', 'Sales', 'Promo', 'StateHoliday']]

# only important or needed columns

# %%
df_store = df_store.rename(columns={
    'Date': 'ds',
    'Sales': 'y'
})

# %%
df_store = df_store.set_index('ds').asfreq('D').reset_index()

# %%
df_store.head()
# Out:
#           ds       y  Promo StateHoliday
# 0 2013-01-02  5530.0    0.0            0
# 1 2013-01-03  4327.0    0.0            0
# 2 2013-01-04  4486.0    0.0            0
# 3 2013-01-05  4997.0    0.0            0
# 4 2013-01-06     NaN    NaN          NaN

# %%
df_store.isnull().sum()
# Out:
# ds                0
# y               160
# Promo           160
# StateHoliday    160
# dtype: int64

# %%
# Fill sales (time-series continuity)
df_store['y'] = df_store['y'].fillna(method='ffill')

# Fill promo (no promo on missing days)
df_store['Promo'] = df_store['Promo'].fillna(0)

# Fill holiday (normal day)
df_store['StateHoliday'] = df_store['StateHoliday'].fillna(0)

# %%
train_df = df_store[:-30]
test_df = df_store[-30:]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #  1. Sales Over Time

# %%
plt.figure(figsize=(12,5))
plt.plot(df_store['ds'], df_store['y'])
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # 2. Year-wise Trend

# %%
df_store['Year'] = df_store['ds'].dt.year

yearly_sales = df_store.groupby('Year')['y'].mean()
yearly_sales.plot(kind='bar', figsize=(8,4))
plt.title("Average Sales Per Year")
plt.show()

# %% [markdown]
# # 3 Monthly Seasonality

# %%
df_store['Month'] = df_store['ds'].dt.month

monthly_sales = df_store.groupby('Month')['y'].mean()
monthly_sales.plot(kind='bar', figsize=(10,4))
plt.title("Average Sales Per Month")
plt.show()

# %% [markdown]
# # 4 Weekly Pattern

# %%
df_store['day_of_week'] = df_store['ds'].dt.dayofweek

day_of_week = df_store.groupby('day_of_week')['y'].mean()
day_of_week.plot(kind='bar', figsize=(8,4))
plt.title("Average Sales Per Week")
plt.show()

# %% [markdown]
# # 5. Sales Distribution

# %%
import seaborn as sns
plt.figure(figsize = (8,4))
sns.histplot(df_store['y'], bins=50, kde=True)
plt.title("Sales Distribution")
plt.show()

# %% [markdown]
# # 6. Boxplot (Outlier Detection)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=df_store['y'])
plt.title("Outlier Detection")
plt.show()

# %% [markdown]
# # Promo vs No Promo

# %%
sns.boxplot(x=df_store['Promo'], y=df_store['y'])
plt.title("Sales vs Promotion")
plt.show()

# %% [markdown]
# # Using Prophet Model

# %%
from prophet import Prophet

# %%
model = Prophet()
model.add_regressor('Promo')
model.fit(df_store)
# Out:
# 03:19:01 - cmdstanpy - INFO - Chain [1] start processing
# 03:19:01 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # Create Future Data

# %%
future = model.make_future_dataframe(periods=30)
future['Promo'] = 0

# %%
forecast = model.predict(future)

# %% [markdown]
# # Plot Forecast

# %%
model.plot(forecast)
plt.title("Sales Forcecast")
plt.show()

# %% [markdown]
# # Components

# %%
model.plot_components(forecast)
plt.show()

# %% [markdown]
# # Rag knowledge base

# %%
knowledge = [
    "Sales are higher on weekends, especially Saturday and Sunday.",
    "Sales tend to decrease mid-week, especially Wednesday and Thursday.",
    "There is a yearly peak in sales around December due to holiday season.",
    "Promotions significantly increase sales compared to non-promo days.",
    "Overall sales trend is slightly decreasing over time.",
]

# %% [markdown]
# # Creating Embeddings

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(
    model_name = "all-MiniLM-L6-v2"
)
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_154400\897108727.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# # Vector Store (FAISS)

# %%
from langchain_community.vectorstores import FAISS

vector_db = FAISS.from_texts(knowledge, embeddings)

# %% [markdown]
# # Retriever

# %%
retriever = vector_db.as_retriever(search_kwargs={'k': 3})

# %% [markdown]
# # LLM (FREE Local)

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

pipe = pipeline(
    "text-generation",
    model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    max_new_tokens=150
)
llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...

# %%
def rag_chain(query):
    docs = retriever.invoke(query)
    
    context = " ".join([doc.page_content for doc in docs])
    
    prompt = f"""
    You are a professional sales analyst.

    Use ONLY the given context to answer.

    Context:
    {context}

    Question:
    {query}

    Give Answer clearly:
    """
    
    return llm.invoke(prompt)

# %%
print(rag_chain("Why do sales increase on weeken?"))
# Out:
# Both `max_new_tokens` (=150) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     You are a professional sales analyst.
#
#     Use ONLY the given context to answer.
#
#     Context:
#     Sales are higher on weekends, especially Saturday and Sunday. Sales tend to decrease mid-week, especially Wednesday and Thursday. Promotions significantly increase sales compared to non-promo days.
#
#     Question:
#     Why do sales increase on weeken?
#
#     Give Answer clearly:
#
# ...
